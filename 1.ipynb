# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('C:/Users/Lenovo/Downloads/High_Value_Dataset__January_2024_20240718.csv')
display(df.head())
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(8, 5))
gender_counts.plot(kind='bar', color=['blue', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
plt.figure(figsize=(8, 5))
plt.hist(df['Age'], bins=10, color='green', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
#    SID Number  TDCJ Number                     Name    Current Facility  \
# 0      671628      2394062    ONOFRE,JESSE TINAJERO            Connally
# 1      686567       311644  PALACIOS,ROBERT LEONARD          Jester III
# 2      770626       449674            FLORES,ISABEL                Pack
# 3      771601      1491019        MOLETT,JOHN HENRY            W. Scott
# 4      799447       248098       DOWDEN,BILLY WAYNE  Hospital Galveston
#
#   Gender      Race  Age Projected Release Maximum Sentence Date  \
# 0      M  Hispanic   88        04/23/2026            04/23/2026
# 1      M  Hispanic   85        09/12/2028            05/12/2036
# 2      M  Hispanic   86        01/01/9999            01/01/9999
# 3      M     Black   81        12/02/2037            12/02/2037
# 4      M     White   87        01/01/9999            01/01/9999
#
#   Parole Eligibility Date  Case Number  County  Offense Code  \
# 0              04/22/2024   2019CR4680   Bexar      36010001
# 1              04/15/2022       320670  Harris      22100000
# 2              09/02/2006  86CR-1234-B  Nueces       9150000
# 3              12/02/2022      1144294  Harris      12990002
# 4              05/24/1981       225031  Harris       9130000
#
#                 TDCJ Offense Sentence Date Offense Date Sentence (Years)  \
# 0      INDEC W/CHILD CONTACT    05/16/2022   08/02/2016              4.0
# 1  BURG HAB W/I SEXUAL ABUSE    10/21/1980   01/28/1980             30.0
# 2        MURDER W/DEADLY WPN    04/13/1987   09/02/1986             Life
# 3           AGG ROBBERY W/DW    02/21/2008   12/03/2007             30.0
# 4             CAPITAL MURDER    04/30/1975   06/28/1974     Capital Life
#
#    Last Parole Decision Next Parole Review Date      Parole Review Status
# 0                   NaN              04/22/2024  IN PAROLE REVIEW PROCESS
# 1  Denied on 05/01/2023                 04/2026     NOT IN REVIEW PROCESS
# 2  Denied on 07/21/2021                 07/2024     NOT IN REVIEW PROCESS
# 3  Denied on 01/24/2024                 01/2025     NOT IN REVIEW PROCESS
# 4  Denied on 11/20/2021                 11/2024     NOT IN REVIEW PROCESS
